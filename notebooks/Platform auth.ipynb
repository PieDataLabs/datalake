# %%
import os
import sys
from PIL import Image
from datalake.credentials import save_credentials

# %% [markdown]
# #### Open the link https://console.piedata.ai/proxy?project_id=64b61f572e9765980a0640d3&action=/login
#
# ###### Log In with Google
#
# ###### And after that go to account tab: the rightest icon on navigation bar (letter C on the image below)

# %%
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2596x200>

# %% [markdown]
# ###### After clicking you will see:

# %%
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1142x890>

# %% [markdown]
# COPY this values into code below

# %%
email = ""
api_key = ""

# %%
save_credentials(email=email, api_key=api_key)

# %% [markdown]
# #### Now you can use other notebooks
